# %% [markdown]
# # Creating the Train dataset

# %% [markdown]
# **Using the free LLaMA 3-70B model from Groq and Pydantic to create clear and consistent training data.**

# %% [markdown]
# ## Import dataset with job offers

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/combined_jobs.csv')

# %%
df.shape
# Out:
# (1079, 6)

# %%
df.head()
# Out:
#                                    Position                Company_Name  \
# 0                                IT Manager  10 Percent Recruiting Ltd.
# 1                       Manager, IT Support                      Procom
# 2        Director of Information Technology   Southampton Financial Inc
# 3  Manager, Information Technology Services         Town of Tillsonburg
# 4                           Systems Manager                       Accor
#
#                               Location Post_Month  Post_Year  \
# 0  Vancouver, British Columbia, Canada       June       2024
# 1             Toronto, Ontario, Canada       June       2024
# 2             Toronto, Ontario, Canada       June       2024
# 3         Tillsonburg, Ontario, Canada       June       2024
# 4           Winnipeg, Manitoba, Canada       June       2024
#
#                                              Details
# 0  Position Title: IT Manager\n\nLocation: Vancou...
# 1  On behalf of our public sector client, PROCOM ...
# 2  Southampton Financials’ Mission: Bring Clarity...
# 3  The Town of Tillsonburg is looking for a Manag...
# 4  Company Description\n\n"Why work for Accor?"\n...

# %%
df = df.head(500)

# %% [markdown]
# ## Generative AI processing

# %%
# We will generate a new column that contains the following JSON object for each job Description in the following dataset

system_message_prompt = """
You are an AI assistant that converts job descriptions into structured JSON data to assist recruiters. Your task is to extract key details from a given job description and format them into a JSON object with the following structure:

{
  "role_summary": "A concise, non-technical summary of the job role. It should describe the primary responsibilities of the role in simple language, avoiding jargon. Focus on what the role does rather than listing requirements.",
  "key_terms": [
    {
      "term": "Technical Term or jargon from the job description",
      "explanation": "A simple explanation of the term in the context of the role. This helps recruiters understand technical jargon without needing domain expertise."
    }
  ],
  "skill_priorities": {
    "must_have": ["List of essential skills required for the role. These are non-negotiable and should be explicitly mentioned in the job description."],
    "nice_to_have": ["List of preferred skills that are beneficial but not mandatory. These are often marked as 'preferred,' 'a plus,' or 'optional' in the job description."]
  },
  "proposed_screening_questions_with_answers": [
       {
           "question": "A role-specific question to assess candidate expertise...",
           "example_answer": "An example of a strong candidate response..."
       },
       {
           "question": "Another relevant question...",
           "example_answer": "A strong answer to the second question..."
       }
  ],
  "red_flags": [
    "Indicators of potential mismatches for the role, offering actionable insights for recruiters based on the job offer. Examples include 'Avoid candidates without cloud experience'."
  ],
  "confidence_score": "A numerical score between 0 and 100 indicating the model's confidence in the accuracy of its analysis."
}

Guidelines:
- Ensure the role summary is written in simple, non-technical language, focusing on primary responsibilities rather than qualifications.
- Extract key technical terms and provide clear, non-technical explanations.
- Identify and categorize skills into 'must-have' and 'nice-to-have' based on explicit mentions in the job description.
- Generate screening questions that assess relevant competencies and provide an example of a strong answer.
- Highlight red flags that indicate potential mismatches, ensuring they are actionable.
- Assign a confidence score (0-100) reflecting the reliability of the extracted insights.

Output only the JSON object without additional text.

"""

# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.11/dist-packages (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.0)

# %%
import re
import groq
import os
import json
import time
from typing import List, Optional
import json
from pydantic import BaseModel
from google.colab import userdata
from pprint import pprint

# %%
llama3_model= 'llama3-70b-8192'

# %%
key_1 = userdata.get('groq_key_1')
key_2 = userdata.get('groq_key_2')
key_3 = userdata.get('groq_key_3')

api_keys = [key_1, key_2, key_3]

# %%
from typing import List, Optional
from pydantic import BaseModel

class KeyTerm(BaseModel):
    term: str
    explanation: str

class SkillPriorities(BaseModel):
    must_have: List[str]
    nice_to_have: List[str]

class ScreeningQuestion(BaseModel):
    question: str
    example_answer: str

class JobAnalysis(BaseModel):
    role_summary: str
    key_terms: List[KeyTerm]
    skill_priorities: SkillPriorities
    proposed_screening_questions_with_answers: List[ScreeningQuestion]
    red_flags: List[str]
    confidence_score: float

# %%
from pydantic import ValidationError
from groq import Groq, APIError, APIConnectionError, RateLimitError
from pydantic import ValidationError
from typing import Union

def analyze_job_with_retries(
    job_description: str,
    prompt: str,
    model_name: str,
    api_keys: list,
    max_retries: int = 3,
    initial_retry_delay: float = 1.0
) -> Union[JobAnalysis, str]:  # Updated return type
    """
    Analyzes a job description with API key rotation on exceptions.

    Args:
        job_description: The job description text to analyze.
        prompt: System prompt for the AI model.
        model_name: Name of the LLM model to use.
        api_keys: List of API keys to rotate through.
        max_retries: Maximum number of retry attempts across all keys.
        initial_retry_delay: Initial delay between retries in seconds (exponential backoff).

    Returns:
        Union[JobAnalysis, str]: Parsed job analysis results or 'Error' if all retries fail.
    """
    retry_delay = initial_retry_delay
    total_attempts = 0

    while total_attempts < max_retries:
        for i, api_key in enumerate(api_keys):
            client = Groq(api_key=api_key)
            try:
                chat_completion = client.chat.completions.create(
                    messages=[
                        {
                            "role": "system",
                            "content": f"{prompt}\n"
                                       f"The JSON object must use the schema: {json.dumps(JobAnalysis.model_json_schema(), indent=2)}",
                        },
                        {
                            "role": "user",
                            "content": f"Analyze this job description:\n\n{job_description}",
                        },
                    ],
                    model=model_name,
                    temperature=0,
                    response_format={"type": "json_object"},
                )
                print(f"Success from {model_name} using API key {i + 1}")
                job_object = JobAnalysis.model_validate_json(
                    chat_completion.choices[0].message.content
                )

                return job_object.model_dump_json()


            except (APIError, APIConnectionError, RateLimitError) as e:
                print(f"API error with key {i + 1}: {str(e)}. Rotating to next key...")
                total_attempts += 1
                if total_attempts >= max_retries:
                    break  # Exit if max retries reached
                time.sleep(retry_delay)
                retry_delay *= 2  # Exponential backoff

            except Exception as e:
                print(f"Unexpected error: {str(e)}. Rotating to next key...")
                total_attempts += 1
                if total_attempts >= max_retries:
                    break  # Exit if max retries reached
                time.sleep(retry_delay)
                retry_delay *= 2

    print("All API keys and retries exhausted. Returning error response.")
    return 'Error'  # Return string 'Error' if all retries fail

# %%
# Example usage
job_desc = """
Note: By applying to this position you will have an opportunity to share your preferred working location from the following: Cambridge, MA, USA; Atlanta, GA, USA; Austin, TX, USA; Seattle, WA, USA.Minimum qualifications:

Master's degree in a quantitative discipline such as Statistics, Engineering, Sciences, or equivalent practical experience
4 years of experience using analytics to solve product or business problems, coding (e.g., Python, R, SQL), querying databases or statistical analysis.
4 years of experience in business visualization tools like Looker, Tableau, etc.

Preferred qualifications:

Master's degree in Computer Science, Economics, or Mathematics, or a related field.
5 years of work experience in data science or quantitative analytics with focus on statistical modeling, Machine Learning, and AI.
Experience with both SQL and Python.
Experience with Machine Learning, AI or AI Pipeline.
Experience in Google Cloud Platform.

About The Job

Cloud Learning Services (CLS) is revolutionizing direct cloud learning. We empower users of all levels with interactive labs and guided experiences to build practical skills on Google Cloud Platform and other leading technologies. Our mission is to make the cloud accessible, engaging, and enjoyable to learn.

As a Business Data Scientist, you will play a key role in uncovering valuable insights from diverse data sources to solve critical business tests. You will address a wide range of exciting projects, from establishing new measurement frameworks to identifying meaningful patterns in large datasets, ultimately empowering stakeholders to make data-driven decisions.

In this role, you will need to be a detail-oriented problem-solver with a strong foundation in data analytics, data visualization, and Artificial Intelligence/Machine Learning. You will solve the real-world problems and a commitment to continuous learning. Exceptional communication and stakeholder management skills are essential, as you will collaborate extensively with cross-functional teams. If you succeed in dynamic environments and are eager to make a real impact with data, we encourage you to apply!

The US base salary range for this full-time position is $166,000-$244,000 + bonus + equity + benefits. Our salary ranges are determined by role, level, and location. Within the range, individual pay is determined by work location and additional factors, including job-related skills, experience, and relevant education or training. Your recruiter can share more about the specific salary range for your preferred location during the hiring process.

Please note that the compensation details listed in US role postings reflect the base salary only, and do not include bonus, equity, or benefits. Learn more about benefits at Google .

Responsibilities

Extract actionable insights from large, complex datasets and build data products like dashboards to operationalize them, driving measurable improvements in Key Performance Indicators (KPIs).
Present and communicate actionable insights and recommendations to executives, leaders, and cross-functional partners, including Product, Engineering, and Marketing teams.
Serve as a peer-reviewer and consultant to other members of the team, fostering a collaborative and knowledge-sharing environment.
Learn and share knowledge of the latest advancements in AI/ML and data science that are relevant to our work.

"""

analysis = analyze_job_with_retries(job_desc, system_message_prompt, llama3_model, api_keys)


# Assuming `analysis` is your JobAnalysis object
pprint(analysis)
# Out:
# Success from llama3-70b-8192 using API key 1
# ('{"role_summary":"As a Business Data Scientist, you will uncover valuable '
#  'insights from diverse data sources to solve critical business tests, '
#  'empowering stakeholders to make data-driven '
#  'decisions.","key_terms":[{"term":"Machine Learning","explanation":"A type of '
#  'Artificial Intelligence that enables computers to learn from data without '
#  'being explicitly programmed."},{"term":"Artificial '
#  'Intelligence","explanation":"The development of computer systems that can '
#  'perform tasks that typically require human intelligence, such as visual '
#  'perception, speech recognition, and decision-making."},{"term":"Google Cloud '
#  'Platform","explanation":"A suite of cloud computing services offered by '
#  'Google, including data analytics, machine learning, and '
#  'storage."},{"term":"SQL","explanation":"A programming language designed for '
#  'managing and manipulating data in relational database management '
#  'systems."},{"term":"Python","explanation":"A high-level programming language '
#  'used for various purposes such as web development, scientific computing, and '
#  'data analysis."}],"skill_priorities":{"must_have":["Master\'s degree in a '
#  'quantitative discipline","4 years of experience using analytics to solve '
#  'product or business problems","4 years of experience in business '
#  'visualization tools like Looker, Tableau, etc."],"nice_to_have":["Master\'s '
#  'degree in Computer Science, Economics, or Mathematics","5 years of work '
#  'experience in data science or quantitative analytics","Experience with '
#  'Machine Learning, AI or AI Pipeline","Experience in Google Cloud '
#  'Platform"]},"proposed_screening_questions_with_answers":[{"question":"Can '
#  'you explain how you would approach solving a complex business problem using '
#  'data analytics?","example_answer":"I would start by identifying the key '
#  'stakeholders and their requirements, then gather relevant data from various '
#  'sources, and finally use statistical modeling and visualization tools to '
#  'present actionable insights."},{"question":"How do you stay updated with the '
#  'latest developments in AI/ML and data science?","example_answer":"I '
#  'regularly read industry blogs and research papers, attend conferences, and '
#  'participate in online forums to stay current with the latest '
#  'advancements."}],"red_flags":["Lack of experience with Google Cloud '
#  'Platform","Insufficient experience in data visualization tools like Looker, '
#  'Tableau, etc.","Inability to communicate complex technical concepts to '
#  'non-technical stakeholders"],"confidence_score":90.0}')

# %%
from tqdm.notebook import tqdm
import time

def process_dataframe(df, system_message_prompt, llama3_model, api_keys):
    tqdm.pandas(desc="Processing job descriptions")

    def safe_analyze(row):
        job_desc = row['Details']
        position = row['Position']
        print(f"Processing position: {position}")

        # Analyze the job description
        result = analyze_job_with_retries(job_desc, system_message_prompt, llama3_model, api_keys)

        # Handle the case where the result is 'Error'
        if result == 'Error':
            print(f"Failed to analyze position: {position}")
            return None  # Or return a default value or error object
        else:
            return result  # Return the JobAnalysis object

    # Use progress_apply to process each row
    df['parsed_description'] = df.progress_apply(safe_analyze, axis=1)
    return df

# Process the DataFrame
analysed_df = process_dataframe(df, system_message_prompt, llama3_model, api_keys)
# Out:
# Processing job descriptions:   0%|          | 0/500 [00:00<?, ?it/s]
# Processing position: IT Manager
# Success from llama3-70b-8192 using API key 1
# Processing position: Manager, IT Support
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Manager, IT Support is a leadership role responsible for managing the daily operations of IT Support, ensuring effective vendor governance, and achieving premium customer service and operational excellence.",\n   "key_terms": [\n      {\n         "term": "ITIL",\n         "explanation": "ITIL is a framework for IT service management that provides best practices for delivering high-quality IT services."\n      },\n      {\n         "term": "ITSM",\n         "explanation": "ITSM is a set of policies, procedures, and processes for managing IT services, focusing on delivering value to customers."\n      },\n      {\n         "term": "CMDB",\n         "explanation": "CMDB stands for Configuration Management Database, which is a repository that stores information about IT assets, services, and their relationships."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "ITIL v3 Foundations certification",\n         "Experience leading an IT Support team",\n         "Experience in IT end user support and business applications",\n         "Demonstrated leadership of end-user support, IT Support operations, desk side support, remote support, and system administration team experience"\n         ],\n         "nice_to_have": [\n            "Knowledge of ITOM",\n            "Implementation of CMDB, integrating with ITSM"\n         ]\n      }\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "What is your experience with ITIL, and how have you implemented it in your previous roles?",\n         "example_answer": "I have implemented ITIL in my previous role by defining and developing processes for incident and change management, which resulted in a 25% reduction in incident resolution time."\n      },\n      {\n         "question": "How do you ensure effective vendor governance in IT Support?",\n         "example_answer": "I ensure effective vendor governance by implementing clear communication channels, setting clear expectations, and regularly reviewing vendor performance to ensure they meet our service level agreements."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in leading an IT Support team",\n      "Inability to adapt to dynamic environments"\n   ],\n   "confidence_score": 90\n'}}. Rotating to next key...
# API error with key 2: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Manager, IT Support is a leadership role responsible for managing the daily operations of IT Support, ensuring effective vendor governance, and achieving premium customer service and operational excellence.",\n   "key_terms": [\n      {\n         "term": "ITIL",\n         "explanation": "ITIL is a framework for IT service management that provides best practices for delivering high-quality IT services."\n      },\n      {\n         "term": "ITSM",\n         "explanation": "ITSM is a set of policies, procedures, and processes for managing IT services, focusing on delivering value to customers."\n      },\n      {\n         "term": "CMDB",\n         "explanation": "CMDB stands for Configuration Management Database, which is a repository that stores information about IT assets, services, and their relationships."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "ITIL v3 Foundations certification",\n         "Experience leading an IT Support team",\n         "Experience in IT end user support and business applications",\n         "Demonstrated leadership of end-user support, IT Support operations, desk side support, remote support, and system administration team experience"\n         ],\n         "nice_to_have": [\n            "Knowledge of ITOM",\n            "Implementation of CMDB, integrating with ITSM"\n         ]\n      }\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "What is your experience with ITIL, and how have you implemented it in your previous roles?",\n         "example_answer": "I have implemented ITIL in my previous role by defining and developing processes for incident and change management, which resulted in a 25% reduction in incident resolution time."\n      },\n      {\n         "question": "How do you ensure effective vendor governance in IT Support?",\n         "example_answer": "I ensure effective vendor governance by implementing clear communication channels, setting clear expectations, and regularly reviewing vendor performance to ensure they meet our service level agreements."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in leading an IT Support team",\n      "Inability to adapt to dynamic environments"\n   ],\n   "confidence_score": 90\n'}}. Rotating to next key...
# API error with key 3: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Manager, IT Support is a leadership role responsible for managing the daily operations of IT Support, ensuring effective vendor governance, and achieving premium customer service and operational excellence.",\n   "key_terms": [\n      {\n         "term": "ITIL",\n         "explanation": "ITIL is a framework for IT service management that provides best practices for delivering high-quality IT services."\n      },\n      {\n         "term": "ITSM",\n         "explanation": "ITSM is a set of policies, procedures, and processes for managing IT services, focusing on delivering value to customers."\n      },\n      {\n         "term": "CMDB",\n         "explanation": "CMDB stands for Configuration Management Database, which is a repository that stores information about IT assets, services, and their relationships."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "ITIL v3 Foundations certification",\n         "Experience leading an IT Support team",\n         "Experience in IT end user support and business applications",\n         "Demonstrated leadership of end-user support, IT Support operations, desk side support, remote support, and system administration team experience"\n         ],\n         "nice_to_have": [\n            "Knowledge of ITOM",\n            "Implementation of CMDB, integrating with ITSM"\n         ]\n      }\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "What is your experience with ITIL, and how have you implemented it in your previous roles?",\n         "example_answer": "I have implemented ITIL in my previous role by defining and developing processes for incident and change management, which resulted in a 25% reduction in incident resolution time."\n      },\n      {\n         "question": "How do you ensure effective vendor governance in IT Support?",\n         "example_answer": "I ensure effective vendor governance by implementing clear communication channels, setting clear expectations, and regularly reviewing vendor performance to ensure they meet our service level agreements."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in leading an IT Support team",\n      "Inability to adapt to dynamic environments"\n   ],\n   "confidence_score": 90\n'}}. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: Manager, IT Support
# Processing position: Director of Information Technology
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The IT Development & Operations Director will lead and manage the IT department, responsible for Development, Operations, Security, and Compliance of the entire IT platform for a growing digital insurance brokerage company.",\n   "key_terms": [\n      {\n              "term": "IT-architecture solutions",\n              "explanation": "Refers to the design and implementation of IT systems and infrastructure to support business operations."\n           },\n           {\n              "term": "AWS stack"",\\n              "explanation": "Refers to a set of cloud computing services offered by Amazon Web Services (AWS) that enable developers to build, deploy, and manage applications and workloads in the cloud.",\n           },\n           {\n              "term": "Angular, React, Vue",\n              "explanation": "These are popular front-end JavaScript frameworks used for building web applications."\n           },\n           {\n              "term": "Sitecore, SQL, Postgres, MongoDB",\n              "explanation": "These are various database management systems and content management systems used for storing and managing data."\n           },\n           {\n              "term": "Salesforce, Mulesoft, Azure Data Warehouse, AWS EC2 and Lambda",\n              "explanation": "These are various cloud-based platforms and services used for integrating, managing, and analyzing data."\n           },\n           {\n              "term": "Guidewire, Duck Creek, and Applied Systems",\n              "explanation": "These are insurance industry-specific platforms used for managing insurance policies, claims, and customer data."\n           }\n        ],\n   "skill_priorities": {\n      "must_have": [\n         "Experience in developing and building out application platforms (preferably in the insurance industry)",\n         "Good understanding of the AWS stack",\n         "Knowledge of security guidelines and frameworks for the web",\n         "Proven experience in IT with at least a bachelor\'s degree, preferably with a specialization in IT",\n         "At least 5 years\' experience in a comparable role"\n      ],\n      "nice_to_have": [\n         "Knowledge of and experience with insurance platforms such as Guidewire, Duck Creek, and Applied Systems",\n         "Experience with the following Technology Stack: Angular, React, Vue, Java, Sitecore, SQL, Postgres, MongoDB, Salesforce, Mulesoft, Azure Data Warehouse, AWS EC2 and Lambda"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you explain your experience with developing and building out application platforms in the insurance industry?",\n         "example_answer": "I have 5 years of experience in the insurance industry, where I developed and built out application platforms using AWS stack and insurance industry-specific platforms such as Guidewire, Duck Creek, and Applied Systems."\n      },\n      {\n         "question": "How do you ensure the quality of the codebase and monitor it constantly?",\n         "example_answer": "I use various tools and frameworks to ensure the quality of the codebase, such as code reviews, unit testing, and integration testing. I also monitor the codebase constantly by using tools such as SonarQube and CodeCoverage."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in developing and building out application platforms in the insurance industry",\n      "Inability to work independently and collaborate with various roles and disciplines within the organization"\n   ],\n   "confidence_score": 90\n}'}}. Rotating to next key...
# API error with key 2: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The IT Development & Operations Director will lead and manage the IT department, responsible for Development, Operations, Security, and Compliance of the entire IT platform for a growing digital insurance brokerage company.",\n   "key_terms": [\n      {\n              "term": "IT-architecture solutions",\n              "explanation": "Refers to the design and implementation of IT systems and infrastructure to support business operations."\n           },\n           {\n              "term": "AWS stack"",\\n              "explanation": "Refers to a set of cloud computing services offered by Amazon Web Services (AWS) that enable developers to build, deploy, and manage applications and workloads in the cloud.",\n           },\n           {\n              "term": "Angular, React, Vue",\n              "explanation": "These are popular front-end JavaScript frameworks used for building web applications."\n           },\n           {\n              "term": "Sitecore, SQL, Postgres, MongoDB",\n              "explanation": "These are various database management systems and content management systems used for storing and managing data."\n           },\n           {\n              "term": "Salesforce, Mulesoft, Azure Data Warehouse, AWS EC2 and Lambda",\n              "explanation": "These are various cloud-based platforms and services used for integrating, managing, and analyzing data."\n           },\n           {\n              "term": "Guidewire, Duck Creek, and Applied Systems",\n              "explanation": "These are insurance industry-specific platforms used for managing insurance policies, claims, and customer data."\n           }\n        ],\n   "skill_priorities": {\n      "must_have": [\n         "Experience in developing and building out application platforms (preferably in the insurance industry)",\n         "Good understanding of the AWS stack",\n         "Knowledge of security guidelines and frameworks for the web",\n         "Proven experience in IT with at least a bachelor\'s degree, preferably with a specialization in IT",\n         "At least 5 years\' experience in a comparable role"\n      ],\n      "nice_to_have": [\n         "Knowledge of and experience with insurance platforms such as Guidewire, Duck Creek, and Applied Systems",\n         "Experience with the following Technology Stack: Angular, React, Vue, Java, Sitecore, SQL, Postgres, MongoDB, Salesforce, Mulesoft, Azure Data Warehouse, AWS EC2 and Lambda"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you explain your experience with developing and building out application platforms in the insurance industry?",\n         "example_answer": "I have 5 years of experience in the insurance industry, where I developed and built out application platforms using AWS stack and insurance industry-specific platforms such as Guidewire, Duck Creek, and Applied Systems."\n      },\n      {\n         "question": "How do you ensure the quality of the codebase and monitor it constantly?",\n         "example_answer": "I use various tools and frameworks to ensure the quality of the codebase, such as code reviews, unit testing, and integration testing. I also monitor the codebase constantly using tools such as SonarQube and CodeCoverage."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in developing and building out application platforms in the insurance industry",\n      "Inability to work with the AWS stack and insurance industry-specific platforms",\n      "Lack of knowledge of security guidelines and frameworks for the web"\n   ],\n   "confidence_score": 90\n}'}}. Rotating to next key...
# API error with key 3: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The IT Development & Operations Director will lead and manage the IT department, responsible for Development, Operations, Security, and Compliance of the entire IT platform for a growing digital insurance brokerage company.",\n   "key_terms": [\n      {\n              "term": "IT-architecture solutions",\n              "explanation": "Refers to the design and implementation of IT systems and infrastructure to support business operations."\n           },\n           {\n              "term": "AWS stack"",\\n              "explanation": "Refers to a set of cloud computing services offered by Amazon Web Services (AWS) that enable developers to build, deploy, and manage applications and workloads in the cloud.",\n           },\n           {\n              "term": "Angular, React, Vue",\n              "explanation": "These are popular front-end JavaScript frameworks used for building web applications."\n           },\n           {\n              "term": "Sitecore, SQL, Postgres, MongoDB",\n              "explanation": "These are various database management systems and content management systems used for storing and managing data."\n           },\n           {\n              "term": "Salesforce, Mulesoft, Azure Data Warehouse, AWS EC2 and Lambda",\n              "explanation": "These are various cloud-based platforms and services used for data integration, analytics, and workflow automation."\n           },\n           {\n              "term": "Guidewire, Duck Creek, and Applied Systems",\n              "explanation": "These are insurance industry-specific platforms used for managing insurance policies and portfolios."\n           }\n       ],\n   "skill_priorities": {\n      "must_have": [\n         "Experience in developing and building out application platforms (preferably in the insurance industry)",\n         "Good understanding of the AWS stack",\n         "Knowledge of security guidelines and frameworks for the web",\n         "In-depth knowledge and experience of (AWS-based) IT-architecture solutions",\n         "Experience with insurance platforms such as Guidewire, Duck Creek, and Applied Systems"\n      ],\n      "nice_to_have": [\n         "Bachelor\'s degree, preferably with a specialization in IT",\n         "At least 5 years\' experience in a comparable role"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you explain your experience with developing and building out application platforms in the insurance industry?",\n         "example_answer": "I have worked on several projects involving the development of insurance platforms using Guidewire and Applied Systems. I have a deep understanding of the AWS stack and have implemented security guidelines and frameworks for web."\n      },\n      {\n         "question": "How do you ensure the quality of the codebase and collaborate with the product owner on improving/refactoring the codebase?",\n         "example_answer": "I use various tools and methodologies to monitor the codebase and ensure it meets the required standards. I work closely with the product owner to identify areas for improvement and implement changes accordingly."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in developing and building out application platforms in the insurance industry",\n      "Inability to work independently and collaborate with various roles and disciplines within the organization"\n   ],\n   "confidence_score": 90\n}'}}. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: Director of Information Technology
# Processing position: Manager, Information Technology Services
# Success from llama3-70b-8192 using API key 1
# Processing position: Systems Manager
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Systems Manager is a leadership role that oversees all technology services, focusing on hardware, operating systems, and security, ensuring professional and friendly service to internal and external guests.",\n   "key_terms": [\n      {\n         "term": "IT Security Policy",\n"explanation": "A set of rules and guidelines that ensure the security and safety of hardware, software, and data in the hotel."\n      },\n      {\n         "term": "Software licensing laws",\n"explanation": "Rules that govern the use and installation of software to ensure compliance with licensing agreements."\n      },\n      {\n         "term": "Help desk tickets",\n"explanation": "Issues or problems reported by hotel staff that require IT support to resolve."\n      },\n   "key_terms": [\n      {\n         "term": "Cisco certification",\n"explanation": "A professional certification that demonstrates expertise in Cisco networking systems and technologies."\n      },\n      {\n         "term": "A+ Certification",\n"explanation": "An entry-level certification that demonstrates basic knowledge of computer hardware, software, and networking technologies."\n      },\n      {\n         "Microsoft Certified System Engineer",\n"explanation": "A professional certification that demonstrates expertise in designing, implementing, and administering Microsoft-based systems."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "A+ Certification",\n         "Microsoft Certified System Engineer",\n         "Cisco certification or equivalent experience"\n      ],\n      "nice_to_have": [\n         "Understanding of hotel operations",\n         "Previous supervisory and training experience"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "How would you ensure compliance in software installation and usage?",\n         "example_answer": "I would review the software licensing agreements and ensure that the software is installed and used in accordance with the agreements."\n      },\n      {\n         "question": "How would you troubleshoot and resolve IT issues reported by hotel staff?",\n         "example_answer": "I would follow the established incident management process, identify the root cause of the issue, and work with the hotel team to implement a solution."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in hotel operations",\n      "Inability to communicate technical information to non-technical staff"\n   ],\n   "confidence_score": 85\n}'}}. Rotating to next key...
# API error with key 2: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Systems Manager is a leadership role that oversees all technology services, focusing on hardware, operating systems, and security, ensuring professional and friendly service to internal and external guests.",\n   "key_terms": [\n      {\n         "term": "IT Security Policy",\n"explanation": "A set of rules and guidelines that ensure the security and safety of hardware, software, and data in the hotel."\n      },\n      {\n         "term": "Software licensing laws",\n"explanation": "Rules that govern the use and installation of software to ensure compliance with licensing agreements."\n      },\n      {\n         "term": "Help desk tickets",\n"explanation": "Issues or problems reported by hotel staff that require IT support to resolve."\n      },\n   "key_terms": [\n      {\n         "term": "Cisco certification",\n"explanation": "A professional certification that demonstrates expertise in Cisco networking systems and technologies."\n      },\n      {\n         "term": "A+ Certification",\n"explanation": "An entry-level certification that demonstrates basic knowledge of computer hardware, software, and networking technologies."\n      },\n      {\n         "Microsoft Certified System Engineer",\n"explanation": "A professional certification that demonstrates expertise in designing, implementing, and administering Microsoft-based systems."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "A+ Certification",\n         "Microsoft Certified System Engineer",\n         "Cisco certification or equivalent experience"\n      ],\n      "nice_to_have": [\n         "Understanding of hotel operations",\n         "Previous supervisory and training experience"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "How would you ensure compliance in software installation and usage?",\n         "example_answer": "I would review the software licensing agreements and ensure that the software is installed and used in accordance with the agreements."\n      },\n      {\n         "question": "How would you troubleshoot and resolve IT issues reported by hotel staff?",\n         "example_answer": "I would follow the established incident management process, identify the root cause of the issue, and work with the hotel team to implement a solution."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in hotel operations",\n      "Inability to communicate technical information to non-technical staff"\n   ],\n   "confidence_score": 85\n}'}}. Rotating to next key...
# API error with key 3: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Systems Manager is a leadership role that oversees all technology services, focusing on hardware, operating systems, and security, ensuring professional and friendly service to internal and external guests.",\n   "key_terms": [\n      {\n         "term": "IT Security Policy",\n"explanation": "A set of rules and guidelines that ensure the security and safety of hardware, software, and data in the hotel."\n      },\n      {\n         "term": "Software licensing laws",\n"explanation": "Rules that govern the use and installation of software to ensure compliance with licensing agreements."\n      },\n      {\n         "term": "Help desk tickets",\n"explanation": "Issues or problems reported by hotel staff that require IT support to resolve."\n      },\n   "key_terms": [\n      {\n         "term": "Cisco certification",\n"explanation": "A professional certification that demonstrates expertise in Cisco networking systems and technologies."\n      },\n      {\n         "term": "A+ Certification",\n"explanation": "An entry-level certification that demonstrates basic knowledge of computer hardware, software, and networking technologies."\n      },\n      {\n         "Microsoft Certified System Engineer",\n"explanation": "A professional certification that demonstrates expertise in designing, implementing, and administering Microsoft-based systems."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "A+ Certification",\n         "Microsoft Certified System Engineer",\n         "Cisco certification or equivalent experience"\n      ],\n      "nice_to_have": [\n         "Understanding of hotel operations",\n         "Previous supervisory and training experience"\n      ]\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "How would you ensure compliance in software installation and usage?",\n         "example_answer": "I would review the software licensing agreements and ensure that the software is installed and used in accordance with the agreements."\n      },\n      {\n         "question": "How would you troubleshoot and resolve IT issues reported by hotel staff?",\n         "example_answer": "I would follow the established incident management process, identify the root cause of the issue, and work with the hotel team to implement a solution."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience in hotel operations",\n      "Inability to communicate technical information to non-technical staff"\n   ],\n   "confidence_score": 85\n}'}}. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: Systems Manager
# Processing position: IT MANAGER
# Success from llama3-70b-8192 using API key 1
# Unexpected error: 1 validation error for JobAnalysis
# key_terms.2.term
#   Input should be a valid string [type=string_type, input_value=['Firewalls', "Internet V...ivilege access control'], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type. Rotating to next key...
# Success from llama3-70b-8192 using API key 2
# Unexpected error: 1 validation error for JobAnalysis
# key_terms.2.term
#   Input should be a valid string [type=string_type, input_value=['Firewalls', "Internet V...ivilege access control'], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Unexpected error: 1 validation error for JobAnalysis
# key_terms.2.term
#   Input should be a valid string [type=string_type, input_value=['Firewalls', "Internet V...ivilege access control'], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: IT MANAGER
# Processing position: Information Technology (IT) Manager
# Success from llama3-70b-8192 using API key 1
# Processing position: IT Manager North America
# Success from llama3-70b-8192 using API key 1
# Unexpected error: 2 validation errors for JobAnalysis
# key_terms.2.term
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# key_terms.2.explanation
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing. Rotating to next key...
# Success from llama3-70b-8192 using API key 2
# Unexpected error: 2 validation errors for JobAnalysis
# key_terms.2.term
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# key_terms.2.explanation
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Unexpected error: 2 validation errors for JobAnalysis
# key_terms.2.term
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing
# key_terms.2.explanation
#   Field required [type=missing, input_value={'skill_priorities': {'mu...'], 'nice_to_have': []}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: IT Manager North America
# Processing position: IT Support Manager
# Success from llama3-70b-8192 using API key 1
# Processing position: Information Technology Operations Manager
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Manage and improve day-to-day IT operations, ensuring efficient and high-performing service delivery across multiple locations.",\n   "key_terms": [\n     {\n       "term": "IT Operations",\n       "explanation": "The management and maintenance of IT systems and infrastructure to ensure efficient service delivery."\n     },\n     {\n       "term": "Infrastructure Function",\n       "explanation": "The planning, installation, maintenance, and upgrade of IT systems and infrastructure."\n     },\n     {\n       "term": "Operational Excellence",\n       "explanation": "A state of high performance and efficiency, where IT operations meet business objectives."\n     },\n     {\n       "skill_priorities": {\n         "must_have": ["5+ years of experience in IT operations", "Leadership/management experience", "Strong technical skills", "Hands-on experience with troubleshooting level 3 tickets", "Strong understanding of IT systems and infrastructure", "Proficiency in managing Active Directory, Windows Server, VMware, network protocols, security controls, backup and antivirus software", "Experience with O365, SharePoint, OneDrive, Windows deployment toolkit, and remote management technologies", "Familiarity with LAN technologies, routing, switching, firewalls, VPN, VoIP and telephony", "Knowledge of PCI compliance"],\n         "nice_to_have": ["Experience in the hospitality industry"]\n       }\n     },\n     {\n       "proposed_screening_questions_with_answers": [\n         {\n           "question": "Can you describe your experience with IT operations and how you\'ve improved service delivery in previous roles?",\n           "example_answer": "I\'ve managed IT operations for 5+ years, and have implemented process improvements that resulted in a 20% reduction in downtime."\n         },\n         {\n           "question": "How do you stay current with the latest IT systems and infrastructure developments?",\n           "example_answer": "I regularly attend industry conferences, participate in online forums, and engage with vendors to stay informed about the latest technologies and trends."\n         }\n       ]\n     },\n     {\n       "red_flags": ["Lack of experience in IT operations management", "Inability to lead and motivate a team", "Limited technical skills", "No experience with IT systems and infrastructure"]\n     },\n     "confidence_score": 90\n     }\n'}}. Rotating to next key...
# API error with key 2: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Manage and improve day-to-day IT operations, ensuring efficient and high-performing service delivery across multiple locations.",\n   "key_terms": [\n     {\n       "term": "IT Operations",\n       "explanation": "The management and maintenance of IT systems and infrastructure to ensure efficient service delivery."\n     },\n     {\n       "term": "Infrastructure Function",\n       "explanation": "The planning, installation, maintenance, and upgrade of IT systems and infrastructure."\n     },\n     {\n       "term": "Operational Excellence",\n       "explanation": "A state of high performance and efficiency, where IT operations meet business objectives."\n     },\n     {\n       "skill_priorities": {\n         "must_have": ["5+ years of experience in IT operations", "Leadership/management experience", "Strong technical skills", "Hands-on experience with troubleshooting level 3 tickets", "Strong understanding of IT systems and infrastructure", "Proficiency in managing Active Directory, Windows Server, VMware, network protocols, security controls, backup and antivirus software", "Experience with O365, SharePoint, OneDrive, Windows deployment toolkit, and remote management technologies", "Familiarity with LAN technologies, routing, switching, firewalls, VPN, VoIP and telephony", "Knowledge of PCI compliance"],\n         "nice_to_have": ["Experience in the hospitality industry"]\n       }\n     },\n     {\n       "proposed_screening_questions_with_answers": [\n         {\n           "question": "Can you describe your experience with IT operations and how you\'ve improved service delivery in previous roles?",\n           "example_answer": "I\'ve managed IT operations for 5+ years, and have implemented process improvements that resulted in a 20% reduction in downtime."\n         },\n         {\n           "question": "How do you stay current with the latest IT systems and infrastructure developments?",\n           "example_answer": "I regularly attend industry conferences, participate in online forums, and engage with vendors to stay informed about the latest technologies and trends."\n         }\n       ]\n     },\n     {\n       "red_flags": ["Lack of experience in IT operations management", "Inability to lead and motivate a team", "Limited technical skills", "No experience with IT systems and infrastructure"]\n     },\n     "confidence_score": 90\n     }\n'}}. Rotating to next key...
# API error with key 3: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Manage and improve day-to-day IT operations, ensuring efficient and high-performing service delivery across multiple locations.",\n   "key_terms": [\n     {\n       "term": "IT Operations",\n       "explanation": "The management and maintenance of IT systems and infrastructure to ensure efficient service delivery."\n     },\n     {\n       "term": "Infrastructure Function",\n       "explanation": "The planning, installation, maintenance, and upgrade of IT systems and infrastructure."\n     },\n     {\n       "term": "Operational Excellence",\n       "explanation": "A state of high performance and efficiency, where IT operations meet business objectives."\n     },\n     {\n       "skill_priorities": {\n         "must_have": ["5+ years of experience in IT operations", "Leadership/management experience", "Strong technical skills", "Hands-on experience with troubleshooting level 3 tickets", "Strong understanding of IT systems and infrastructure", "Proficiency in managing Active Directory, Windows Server, VMware, network protocols, security controls, backup and antivirus software", "Experience with O365, SharePoint, OneDrive, Windows deployment toolkit, and remote management technologies", "Familiarity with LAN technologies, routing, switching, firewalls, VPN, VoIP and telephony", "Knowledge of PCI compliance"],\n         "nice_to_have": ["Experience in the hospitality industry"]\n       }\n     },\n     {\n       "proposed_screening_questions_with_answers": [\n         {\n           "question": "Can you describe your experience with IT operations and how you\'ve improved service delivery in previous roles?",\n           "example_answer": "I\'ve managed IT operations for 5+ years, and have implemented process improvements that resulted in a 20% reduction in downtime."\n         },\n         {\n           "question": "How do you stay current with the latest IT systems and infrastructure developments?",\n           "example_answer": "I regularly attend industry conferences, participate in online forums, and engage with vendors to stay informed about the latest technologies and trends."\n         }\n       ]\n     },\n     {\n       "red_flags": ["Lack of experience in IT operations management", "Inability to lead and motivate a team", "Limited technical skills", "No experience with IT systems and infrastructure"]\n     },\n     "confidence_score": 90\n     }\n'}}. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: Information Technology Operations Manager
# Processing position: IT Service Center Director
# Success from llama3-70b-8192 using API key 1
# Processing position: Manager, Information Technology Operations
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "The Manager, Information Technology Operations is responsible for overseeing the day-to-day functions of the Information & Business Technology department\'s Infrastructure and Support, ensuring operational targets are met, and leading a small team of IT support colleagues.",\n   "key_terms": [\n      {\n         "term": "Data center",\n         "explanation": "A large group of networked computer servers used for remote storage, processing, and distribution of data."\n      },\n      {\n         "term": "Network infrastructure",\n         "explanation": "The underlying systems and structures needed to connect devices and allow communication between them."\n      },\n      {\n         "term": "Server OS",\n         "explanation": "An operating system that manages data and applications on a server."\n      },\n      {\n         "term": "Application upgrades",\n         "explanation": "Improvements made to software applications to enhance performance, security, or functionality."\n      },\n      {\n         "term": "Risk assessments",\n         "explanation": "Evaluations of potential risks that could impact operations, data, or systems."\n      },\n      {\n         "term": "Contingency procedures",\n         "explanation": "Plans in place to respond to unexpected events or disruptions\\n      },\\n      {\\n         "term": "SLAs",\\n         "explanation": "Service Level Agreements that outline expected performance and quality standards."\n      },\n      {\n         "term": "IT systems\' security",\n         "explanation": "Measures taken to protect IT systems from unauthorized access, use, disclosure, disruption, modification, or destruction."\n      },\n      {\n         "term": "NIST 800-53",\n         "explanation": "A set of guidelines for information security controls published by the National Institute of Standards and Technology."\n      },\n      {\n         "term": "ISO/IEC 27001/27002",\n         "explanation": "International standards for information security management systems."\n      },\n      {\n         "term": "CIS Controls v7/v8",\n         "explanation": "A set of best practices for cybersecurity controls published by the Center for Internet Security."\n      },\n      {\n         "term": "VMWare virtualized environments",\n         "explanation": "Software that allows multiple virtual machines to run on a single physical machine."\n      },\n      {\n         "term": "Microsoft SQL Server",\n         "explanation": "A relational database management system used to store and manage data."\n      },\n      {\n         "term": "TSQL",\n         "explanation": "A language used to manage and manipulate data in relational database management systems."\n      },\n      {\n         "term": "Microsoft Office 365",\n         "explanation": "A suite of productivity software including Word, Excel, and PowerPoint."\n      },\n      {\n         "term": "Sharepoint",\n         "explanation": "A collaboration platform used for document management and sharing."\n      },\n      {\n         "term": "OneDrive",\n         "explanation": "A cloud-based storage service used to store and share files."\n      },\n      {\n         "term": "IAM",\n         "explanation": "Identity and Access Management, a system used to manage user identities and access to resources."\n      },\n      {\n         "term": "MFA",\n         "explanation": "Multi-Factor Authentication, a security process that requires multiple forms of verification."\n      },\n      {\n         "term": "ERP",\n         "explanation": "Enterprise Resource Planning, a system used to manage business operations and resources."\n      },\n      {\n         "term": "SAP R/3",\n         "explanation": "An Ente ...
# ...
# Failed to analyze position: Data Scientist, Executive Analytics
# Processing position: Senior Data Scientist - Deep Learning focus
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499068, Requested 1865. Please try again in 2m41.0984s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499376, Requested 1865. Please try again in 3m34.290199999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 3: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Lead the development and deployment of deep learning models for device disaggregation and energy analysis, working with large datasets and collaborating with cross-functional teams,\\n   "key_terms": [\\n      {\\n         "term": "Deep learning",\\n         "explanation": "A subfield of machine learning that uses neural networks to analyze and interpret data."\n      },\n      {\n         "term": "Device disaggregation",\n         "explanation": "The process of breaking down energy usage data into individual devices within a home."\n      },\n      {\n         "term": "Time series analysis",\n         "explanation": "A method of analyzing data points in a sequence, used to identify patterns and trends over time."\n      },\n      {\n         "term": "Embedded systems",\n         "explanation": "Computer systems with a specific function, used in devices such as electrical meters."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "Advanced degree in Computer Science, Machine Learning, Statistics, Electrical Engineering, Computer Engineering, or a related field",\n         "5+ years of experience in data science with a strong focus on deep learning",\n         "Experience in training and deploying deep neural networks using popular frameworks",\n         "Solid understanding of deep learning architectures and their applications",\n         "Proficiency in programming languages such as Python and experience with relevant libraries"\n      ],\n      "nice_to_have": []\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you describe a project where you developed and deployed a deep learning model for time series analysis?",\n         "example_answer": "In my previous role, I developed a deep learning model using LSTM networks to predict energy usage patterns of households. I deployed the model on cloud infrastructure and achieved an accuracy of 90%."\n      },\n      {\n         "question": "How do you stay up-to-date with the latest advancements in deep learning research and technologies?",\n         "example_answer": "I regularly read research papers and articles on deep learning, and I participate in conferences and meetups to network with other professionals in the field."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience with deep learning frameworks such as TensorFlow, PyTorch, or Keras",\n      "Inability to communicate complex technical concepts to non-technical stakeholders"\n   ],\n   "confidence_score": 95\n'}}. Rotating to next key...
# All API keys and retries exhausted. Returning error response.
# Failed to analyze position: Senior Data Scientist - Deep Learning focus
# Processing position: Data Scientist (Marketing Science)
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 498963, Requested 1445. Please try again in 1m10.4124s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499271, Requested 1445. Please try again in 2m3.6112s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Machine Learning Engineer - Early in Career
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 498864, Requested 2355. Please try again in 3m30.4914s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499171, Requested 2355. Please try again in 4m23.673199999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Manufacturing Data Scientist
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 498706, Requested 2755. Please try again in 4m12.326399999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499013, Requested 2755. Please try again in 5m5.4862s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Machine Learning Research Engineer/Scientist
# API error with key 1: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Develop and implement AI agents for specialized government tasks, bridging research and practical application in a fast-paced startup environment.",\n   "key_terms": [\n      {\n         "term": "AI agents",\n         "explanation": "Software programs that perform tasks autonomously, in this case, for specialized government tasks."\n      },\n      {\n         "term": "ML/RL theory",\n         "explanation": "Machine Learning and Reinforcement Learning concepts applied to develop AI agents."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "Strong portfolio of research projects",\n         "Experience working at a top AI/ML company"\n      ],\n      "nice_to_have": []\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you share an example of a research project you led that had a significant impact on AI development?",\n         "example_answer": "I developed an AI model that improved the accuracy of disease diagnosis by 30%. I led a team of researchers to implement the model in a real-world setting, resulting in improved patient outcomes."\n      },\n      {\n         "question": "How do you stay current with the latest developments in AI research and its applications?",\n         "example_answer": "I regularly attend conferences, read research papers, and participate in online forums to stay updated on the latest advancements in AI."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience working in a fast-paced startup environment,\\n      "Inability to relocate to New York, NY for on-site work"\\n   ],\\n   "confidence_score": 90\\n}}'}}. Rotating to next key...
# API error with key 2: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "role_summary": "Develop and implement AI agents for specialized government tasks, bridging research and practical application in a fast-paced startup environment.",\n   "key_terms": [\n      {\n         "term": "AI agents",\n         "explanation": "Software programs that perform tasks autonomously, in this case, for specialized government tasks."\n      },\n      {\n         "term": "ML/RL theory",\n         "explanation": "Machine Learning and Reinforcement Learning concepts applied to develop AI agents."\n      }\n   ],\n   "skill_priorities": {\n      "must_have": [\n         "Strong portfolio of research projects",\n         "Experience working at a top AI/ML company"\n      ],\n      "nice_to_have": []\n   },\n   "proposed_screening_questions_with_answers": [\n      {\n         "question": "Can you share an example of a research project you led that had a significant impact on AI development?",\n         "example_answer": "I developed an AI model that improved the accuracy of disease diagnosis by 30%. I led a team of researchers to implement the model in a real-world setting, resulting in improved patient outcomes."\n      },\n      {\n         "question": "How do you stay current with the latest developments in AI research and its applications?",\n         "example_answer": "I regularly attend conferences, read research papers, and participate in online forums to stay updated on the latest advancements in AI."\n      }\n   ],\n   "red_flags": [\n      "Lack of experience working in a fast-paced startup environment,\\n      "Inability to relocate to New York, NY for on-site work"\\n   ],\\n   "confidence_score": 90\\n}}'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Scientist, Data
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499827, Requested 2886. Please try again in 7m48.774599999s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500134, Requested 2886. Please try again in 8m41.9706s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Senior Data Scientist (AI & ML Expert)
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499794, Requested 1495. Please try again in 3m42.6228s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500101, Requested 1495. Please try again in 4m35.8018s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Machine Learning Operations (MLOps) Engineer
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499765, Requested 1854. Please try again in 4m39.693s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 500072, Requested 1854. Please try again in 5m32.888s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Data Scientist - TikTok Live
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499672, Requested 2649. Please try again in 6m40.991s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499980, Requested 2649. Please try again in 7m34.181s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3
# Processing position: Data Scientist, Cloud Learning Services
# API error with key 1: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jb7a6vtvfbpr3d8gja0hcxkg` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499510, Requested 2214. Please try again in 4m57.846s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# API error with key 2: Error code: 429 - {'error': {'message': 'Rate limit reached for model `llama3-70b-8192` in organization `org_01jtjka3d4e5fskxphdwf34pj3` service tier `on_demand` on tokens per day (TPD): Limit 500000, Used 499818, Requested 2214. Please try again in 5m51s. Need more tokens? Upgrade to Dev Tier today at https://console.groq.com/settings/billing', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}. Rotating to next key...
# Success from llama3-70b-8192 using API key 3

# %%
analysed_df.head()
# Out:
#                                     Position                Company_Name  \
# 0                                 IT Manager  10 Percent Recruiting Ltd.
# 3   Manager, Information Technology Services         Town of Tillsonburg
# 6        Information Technology (IT) Manager            Alpha Auto Group
# 8                         IT Support Manager        Logistec Corporation
# 10                IT Service Center Director               Leclerc Foods
#
#                                Location Post_Month  Post_Year  \
# 0   Vancouver, British Columbia, Canada       June       2024
# 3          Tillsonburg, Ontario, Canada       June       2024
# 6               Ottawa, Ontario, Canada       June       2024
# 8              Montreal, Quebec, Canada       June       2024
# 10          Brockville, Ontario, Canada       June       2024
#
#                                               Details  \
# 0   Position Title: IT Manager\n\nLocation: Vancou...
# 3   The Town of Tillsonburg is looking for a Manag...
# 6   Job Description\n\nInterested in developing or...
# 8   CAREER OPPORTUNITY AT LOGISTEC\n\nLOGISTEC off...
# 10  Leclerc is a family business with 117 years of...
#
#                                    parsed_description
# 0   {"role_summary":"The IT Manager will oversee I...
# 3   {"role_summary":"The Manager, Information Tech...
# 6   {"role_summary":"The Information Technology Ma...
# 8   {"role_summary":"Oversee the day-to-day operat...
# 10  {"role_summary":"Manage the IT Service Center,...

# %%
analysed_df.shape
# Out:
# (500, 7)

# %%
pd.isna(analysed_df).sum()
# Out:
# Position                0
# Company_Name            0
# Location                0
# Post_Month              0
# Post_Year               0
# Details                 0
# parsed_description    130
# dtype: int64

# %%
analysed_df = analysed_df.dropna()

# %%
analysed_df.shape
# Out:
# (370, 7)

# %%
analysed_df.to_csv('analysed_jobs_with_analysis.csv', index=False)
